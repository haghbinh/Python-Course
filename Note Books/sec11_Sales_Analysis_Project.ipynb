# %% [markdown]
# <h1 style="text-align: justify; direction:rtl">
#  پروژه تحلیل داده‌های فروش
# </h1>
#
# [Download Superstore Dataset](https://github.com/haghbinh/Python-Course/raw/master/Note%20Books/Datasets/Superstore.xlsx)
#
# ---
# <p style="text-align: justify; direction:rtl">
# در این پروژه، شما با استفاده از ابزارهای pandas و NumPy داده‌های فروش یک کسب‌وکار را تحلیل خواهید کرد.
# داده‌ها شامل اطلاعاتی مانند تاریخ سفارش، تاریخ ارسال، مشتریان، محصولات، فروش، تخفیف و سود هستند.
# ستون‌های موجود در داده‌ها عبارتند از:
# </p>
#
#
# 1. **Row ID**: شماره‌ی یکتا برای هر رکورد.
# 2. **Order ID**: شناسه‌ی سفارش.
# 3. **Order Date**: تاریخ ثبت سفارش.
# 4. **Ship Date**: تاریخ ارسال سفارش.
# 5. **Ship Mode**: روش ارسال سفارش.
# 6. **Customer ID**: شناسه‌ی مشتری.
# 7. **Customer Name**: نام مشتری.
# 8. **Segment**: نوع مشتری (مصرف‌کننده، شرکتی، یا خانه‌دار).
# 9. **Country**: کشور.
# 10. **City**: شهر.
# 11. **State**: ایالت.
# 12. **Postal Code**: کد پستی.
# 13. **Region**: منطقه‌ی جغرافیایی.
# 14. **Product ID**: شناسه‌ی محصول.
# 15. **Category**: دسته‌بندی محصول.
# 16. **Sub-Category**: زیرمجموعه‌ی دسته‌بندی.
# 17. **Product Name**: نام محصول.
# 18. **Sales**: مبلغ فروش.
# 19. **Quantity**: تعداد محصولات.
# 20. **Discount**: درصد تخفیف.
# 21. **Profit**: سود حاصل از فروش.
#
# ---

# %% [markdown]
# <h2 style="text-align: justify; direction:rtl">
# سوالات
# </h2>
#
# <div dir="rtl" style="text-align: justify;">
#     <ol>
#         <li>داده‌ها را با استفاده از pandas بارگذاری کرده و ۱۰ سطر اول آن را نمایش دهید. خلاصه‌ای از ستون‌های Sales، Quantity، Discount و Profit ارائه دهید.</li>
#         <li>بررسی کنید آیا مقادیر گمشده در داده‌ها وجود دارد. اگر وجود دارد، تصمیم بگیرید که چگونه با آن‌ها برخورد کنید و دلیل تصمیم خود را توضیح دهید.</li>
#         <li>۵ مشتری برتر را بر اساس مجموع فروش شناسایی کنید و فروش آن‌ها را با نمودار میله‌ای نمایش دهید.</li>
#         <li>داده‌ها را بر اساس Region گروه‌بندی کرده و مجموع Sales و Profit را برای هر منطقه محاسبه کنید. منطقه‌ای را که بالاترین حاشیه سود را دارد مشخص کنید.</li>
#         <li>تمامی سفارشاتی که Discount آن‌ها بیشتر از ۲۰٪ و Profit آن‌ها منفی است را فیلتر کنید و ستون‌های Order ID، Product Name و Profit را نمایش دهید.</li>
#         <li>ستون Order Date را به فرمت تاریخ تبدیل کنید و نمودار سری زمانی از مجموع فروش ماهانه رسم کنید.</li>
#         <li>میانگین زمان ارسال (Ship Date - Order Date) را برای تمامی سفارشات محاسبه کنید و روش ارسال (Ship Mode) با کمترین میانگین زمان ارسال را مشخص کنید.</li>
#         <li>داده‌ها را بر اساس ستون‌های Category و Sub-Category گروه‌بندی کرده و مجموع Profit را محاسبه کنید. زیردسته‌ای که بیشترین سود را در هر دسته‌بندی دارد، شناسایی کنید.</li>
#         <li>۱۰ محصول برتر با بالاترین فروش را شناسایی کرده و با استفاده از نمودار میله‌ای افقی نمایش دهید.</li>
#         <li>رابطه بین Discount و Profit را با استفاده از نمودار پراکندگی تحلیل کنید و یافته‌های خود را توضیح دهید.</li>
#         <li>مشتریان را بر اساس Segment گروه‌بندی کرده و مجموع فروش و سود را برای هر بخش محاسبه کنید. عملکرد بخش‌ها را با نمودار میله‌ای گروهی مقایسه کنید.</li>
#         <li>ماتریس همبستگی بین ستون‌های Sales، Quantity، Discount و Profit را ایجاد کنید و روابط بین آن‌ها را تحلیل کنید. پیشنهاداتی برای بهبود سودآوری ارائه دهید.</li>
#     </ol>
# </div>
